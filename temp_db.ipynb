# %%
import sqlite3

# %%
conn = sqlite3.connect("fintrackai.db")

# %%
cur = conn.cursor()

# %%
cur.execute('''
         CREATE TABLE USER(
             USER_ID INT PRIMARY KEY,
             USER_NAME VARCHAR(60),
             GENDER VARCHAR(20),
             EMAIL VARCHAR(100),
             PASSWORD_HASH TEXT,
             CREATED_AT DATETIME    
         )   
            ''')

# %%
conn.commit()

# %%
cur.execute('''
         CREATE TABLE VERIFICATION(
             OTP_ID INT PRIMARY KEY,
             USER_ID INT,
             EMAIL_OTP INT,
             OTP_EXP DATETIME,
             OTP_CREATION DATETIME,
             OTP_STATUS VARCHAR(30) CHECK (OTP_STATUS IN("VERIFIED","NOT VERIFIED")),
             FOREIGN KEY(USER_ID) REFERENCES USER(USER_ID)
         )
         ''')

# %%
conn.commit()

# %%
cur.execute('''
CREATE TABLE IF NOT EXISTS INCOME_PROFILES (
    PROFILE_ID INT PRIMARY KEY,
    USER_ID INT,
    INCOME_TYPE VARCHAR(40) CHECK(INCOME_TYPE IN("SALARIED","PROFESSIONAL","BUSINESS","OTHER")),
    MONTHLY_INCOME FLOAT,
    ADDITIONAL_INCOME_TYPE VARCHAR(50) CHECK(ADDITIONAL_INCOME_TYPE IN("STOCK","INVESTEMENTS","BUSINESS","OTHERS")),
    ADDITIONAL_MONTHLY_INCOME FLOAT,
    DEPENDANTS INT CHECK(DEPENDANTS<20),
    CREATED_AT DATETIME,
    UPDATED_AT DATETIME,
    FOREIGN KEY(USER_ID) REFERENCES USER(USER_ID)
)
''')

# %%
conn.commit()

# %%
cur.execute('''
        CREATE TABLE EXPENSEPROFILE(
            EXPENSE_ID INT PRIMARY KEY,
            USER_ID INT,
            GROCERIES FLOAT,
            TRAVEL FLOAT,
            MEDFIT FLOAT,
            LEP FLOAT,
            MONTHLY_RENT FLOAT,
            M_BILLS FLOAT,
            FASHION FLOAT,
            ENTERTAINMENT FLOAT,
            EDUCATION FLOAT,
            EMSAVING FLOAT,
            MISCELLANEOUS FLOAT,
            CREATED_AT DATETIME,
            FOREIGN KEY(USER_ID) REFERENCES USER(USER_ID)
        )
        ''')

# %%
conn.commit()

# %%
cur.execute('''
        CREATE TABLE GOALS(
            GOALID INT PRIMARY KEY,
            USER_ID INT,
            GOAL_NAME VARCHAR(100),
            START_DATE DATETIME,
            END_DATE DATETIME,
            GOAL_AMOUNT FLOAT,
            MONTHLY_SAVING_T FLOAT,
            GOAL_STATUS VARCHAR(50) CHECK(GOAL_STATUS IN("ACTIVE","PAUSED","ACHIEVED","EXPIRED","INACTIVE")),
            CREATED_AT DATETIME,
            UPDATED_AT DATETIME,
            FOREIGN KEY(USER_ID) REFERENCES USER(USER_ID))
            

     
        ''')

# %%
conn.commit()

# %%
cur.execute('''
        CREATE TABLE GOAL_HISTORY(
        HISTORY_ID INT PRIMARY KEY,
        GOALID INT,
        CREATED_AT DATETIME,
        SAVE_MONTH FLOAT,
        FOREIGN KEY(GOALID) REFERENCES GOALS(GOALID))
     
        ''')

# %%
conn.commit()

# %%
import datetime

# %%
cur.execute(f'''
    INSERT INTO USER VALUES(2,"paul","MALE","PAUL@GMAIL.COM","JHVCUYWFWEFSADT7F875JHV3296","{datetime.datetime.now()}")
        ''')

# %%
conn.commit()

# %%
cur.execute("SELECT * FROM USER")
cur.fetchall()
# Out:
# [(2,
#   'paul',
#   'MALE',
#   'PAUL@GMAIL.COM',
#   'JHVCUYWFWEFSADT7F875JHV3296',
#   '2026-03-26 18:18:40.286015'),
#  (3,
#   'Binaya Kumar Meher',
#   'Male',
#   'binaya@gmail.com',
#   'scrypt:32768:8:1$m58xuEYXqYFd6DK8$28cfd7310da6049a61c01a075bfd563d41bbfa8d0a5b0b5f12dc8b54e14c17ff407793c58fd13d4af28673eac239a91876a12a23cd41ae0e6705959aa8a5c2a7',
#   '2026-03-26 19:17:47.526585'),
#  (4,
#   'Nelson Meher',
#   'Male',
#   'nelson@gmail.com',
#   'scrypt:32768:8:1$cDdoRW7vFHAZsJuH$51166381fd8138701894692b0219423bf48e29db2530da32be780e347a06614fbafcfb86891beab8c06c2fce8d5ed19b10027822732be0d003e8bc5917f5b3f9',
#   '2026-03-26 21:06:59.683232'),
#  (5,
#   'Vinay Kumar',
#   'Male',
#   'vinaya269v@gmail.com',
#   'scrypt:32768:8:1$ppBk2Bu3t9DSXA0d$9d262ebd59f31c1e0356168ae400d8b2d1e0a82b31ab9d49230666ad2617a7d927261ed60906b9fbaeaf508e45857496b40af1aabd0f8c0efe8731d8a128be8b',
#   '2026-03-27 11:15:39.626094'),
#  (6,
#   'Nelson Meher',
#   'Male',
#   'nelsonmeher358@gmail.com',
#   'scrypt:32768:8:1$YxzAiYPPfjD3D4OH$f0682b566eb34be62ab49bbbb56f9f06a3a2a283e80ef2c1534f1551754e5b17e70b7b0922e4bf24cab126d94a3b5984a20ca7062e10eb8ac1e4deeaa42ecb42',
#   '2026-03-27 13:43:48.299488'),
#  (7,
#   'binaya test',
#   'Male',
#   'nelsanmeher@gmail.com',
#   'scrypt:32768:8:1$dPUQIY4Q3exuSQ0d$bb7ae9497c4838ff36161fe0159808d16c2e61af20679ea4456d2a8bdc45d1e459a2b12626ac9425139d3daf20e6aad4fd254ca17853d4dfce5a56fcdef273f8',
#   '2026-03-27 14:46:43.150556')]

# %%
cur.execute("")

# %%
cur.execute("PRAGMA table_info(USER)")
print(cur.fetchall())
# Out:
# [(0, 'USER_ID', 'INT', 0, None, 1), (1, 'USER_NAME', 'VARCHAR(60)', 0, None, 0), (2, 'GENDER', 'VARCHAR(20)', 0, None, 0), (3, 'EMAIL', 'VARCHAR(100)', 0, None, 0), (4, 'PASSWORD_HASH', 'TEXT', 0, None, 0), (5, 'CREATED_AT', 'DATETIME', 0, None, 0)]

# %%
cur.execute('''
    ALTER TABLE USER RENAME TO USER_OLD
     
            ''')

# %%
conn.commit()

# %%
cur.execute('''
        CREATE TABLE USER(
            USER_ID INT PRIMARY KEY,
            USER_NAME VARCHAR(40),
            GENDER VARCHAR(20),
            EMAIL VARCHAR(100),
            PASSWORD_HASH TEXT,
            CREATED_AT DATETIME
        )
        ''')

# %%
conn.commit()

# %%
cur.execute('''
            INSERT INTO USER (USER_ID, USER_NAME, GENDER, EMAIL, PASSWORD_HASH, CREATED_AT)
SELECT USER_ID, USER_NAME, GENDER, EMAIL, PASSWORD_HASH, CREATED_AT
FROM USER_OLD;
            ''')

# %%
conn.commit()

# %%
cur.execute('''
            DROP TABLE USER_OLD;
            
            ''')

# %%
conn.commit()

# %%
cur.execute("INSERT INTO VERIFICATION VALUES(1,2,6057,1038464.56,'2025-03-04 15:20:30','VERIFIED')")
conn.commit()

# %%
cur.execute("""
DELETE FROM user
WHERE email = 'vinaya269v@gmail.com'
OR email = 'nelsonmeher358@gmail.com'
OR email = 'nelsanmeher@gmail.com'
OR email = 'nelsonmeher007@gmail.com'
OR email = 'nelsanmeher73@gmail.com';
           """)

# %%
conn.commit()

# %%
cur.execute("""
    SELECT * FROM INCOME_PROFILES;        
            """)
cur.fetchall()
# Out:
# [(1,
#   5,
#   'SALARIED',
#   6632776.0,
#   None,
#   0.0,
#   3,
#   '2026-03-31 04:15:43.506888',
#   '2026-03-31 04:15:43.506888'),
#  (2,
#   5,
#   'SALARIED',
#   8789789.0,
#   None,
#   0.0,
#   3,
#   '2026-03-31 04:16:00.424338',
#   '2026-03-31 04:16:00.424338'),
#  (3,
#   5,
#   'SALARIED',
#   8789789.0,
#   None,
#   0.0,
#   3,
#   '2026-03-31 04:16:01.636834',
#   '2026-03-31 04:16:01.636834'),
#  (4,
#   5,
#   'SALARIED',
#   90000.0,
#   'BUSINESS',
#   40000.0,
#   4,
#   '2026-03-31 04:16:10.339882',
#   '2026-03-31 04:16:10.339882'),
#  (5,
#   5,
#   'SALARIED',
#   666666.0,
#   None,
#   0.0,
#   3,
#   '2026-03-31 18:03:33.327832',
#   '2026-03-31 18:03:33.327832'),
#  (6,
#   5,
#   'SALARIED',
#   60000.0,
#   'BUSINESS',
#   50000.0,
#   5,
#   '2026-03-31 18:10:02.804538',
#   '2026-03-31 18:10:02.804538'),
#  (7,
#   5,
#   'SALARIED',
#   60000.0,
#   'BUSINESS',
#   40000.0,
#   3,
#   '2026-03-31 22:10:55.305517',
#   '2026-03-31 22:10:55.305517'),
#  (8,
#   5,
#   'SALARIED',
#   60000.0,
#   'BUSINESS',
#   80000.0,
#   3,
#   '2026-04-01 12:52:07.699577',
#   '2026-04-01 12:52:07.699577'),
#  (9,
#   5,
#   'SALARIED',
#   60000.0,
#   'STOCK',
#   12000.0,
#   1,
#   '2026-04-01 12:54:01.480444',
#   '2026-04-01 12:54:01.480444')]

# %%
cur.execute("""
    DELETE FROM GOALS
WHERE GOALID IS NULL;        
            """)
conn.commit()
